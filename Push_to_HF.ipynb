# %% [markdown]
# <a href="https://colab.research.google.com/github/somendrew/GenAI_Course/blob/main/Push_to_HF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets huggingface_hub

# %%
from google.colab import userdata
from huggingface_hub import login

login(userdata.get("HF_TOKEN"))

# %%
from datasets import load_dataset

dataset = load_dataset("csv", data_files="/content/dataset.csv")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset.push_to_hub("somendrew/weather-dataset")
